# %% [markdown]
# **Jupyter Notebook** is an interleaved list of `code` and _markdown_ cells that collectively tell a data science story

# %% [markdown]
# **Markdown** is a markup language that you can use to add formatting to plain text.

# %%
print("hello from a code cell!")
# Out:
# hello from a code cell!

# %% [markdown]
# # This is a a Level One Header
#
# ## This is a Level Two Header
# This is the first line in the paragraph.
# This is on the same line.
#
# If we want a hard break: two new lines
#
# Next line
#
# Soft break: 2 spaces and a new line
# Next line

# %% [markdown]
# ## Formatting
# We can **bold** *italize* ~~strikethrough~~ `code format`
#
# ```python
# for i in range(5):
#     print(i)
# ```
#
# >This is a
# block quote
#
# This is not

# %% [markdown]
# ## Lists
#
# **Unordered List**
# - Item A
# - Item B
# - Item C
#
# **Ordered List**
# 1. Item A
# 1. Item B
# 1. Item C
#
# **Nest and Mix List Types**
# 1. Item 1
# 1. Item 2
#     - Item 2.A
#     - Item 2.B
# 1. Item 3
#     1. Item 3.1
#     1. Item 3.2

# %% [markdown]
# ## Links
#
# Shows the link: https://www.markdowntutorial.com/
#
# I recommend you do [this](https://www.markdowntutorial.com/)

# %% [markdown]
# ## Images
#
# ![I heart markdown](https://blog.cyon.ch/wp-content/uploads/2016/05/i-love-markdown.png)
#
# <!-- This is a comment! -->
#
# <img src=https://blog.cyon.ch/wp-content/uploads/2016/05/i-love-markdown.png width="200"/>

# %% [markdown]
# ## Tables
# |Name       |Pts    |Class  |
# |-          |-      |-      |
# |Ben Gregg  |273    |Sr     |
# |Braden Huff|324    |So     |

# %% [markdown]
# ## Latex (Math Mode)
#
# Latex is a mathematical typesetting language/framework used for writing documents and typesettig nice math expressions/formulas.
# We will only use Latex's math mode in this class
#
# Subscripts: $ x_i x_{i+1}  $
#
# $$ x_i $$
#
# Superscripts: $x^ix^{i+1}$
#
# Symbols over characters: $\overline{x+1} \widehat{x+1}$
#
# Special Characters: $\pi \mu \sigma$
#
# Square roots: $\sqrt{x_{i+1} + y + z}$
#
# Fractions: $\frac{1}{\sqrt{x_{i+1}+y}}$
#
# Sums: $\sum_{i=1}^{n} x_i$
#
# Fancy symbols: $x * y$ vs $x \times y$

# %%
import importlib
import utils

utils.say_hello()

importlib.reload(utils)
utils.say_hello()
# Out:
# hello from utils!
# byebye
# hello from utils!
# byebye
